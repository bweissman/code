-- %%
USE master
GO
IF EXISTS(SELECT * FROM sys.databases WHERE name = 'COVID')
    DROP DATABASE COVID
GO
CREATE DATABASE COVID
GO
USE COVID

-- %%
CREATE SCHEMA [mi]
GO
CREATE SCHEMA [dp]
GO
CREATE SCHEMA [sp_parquet]
GO
CREATE SCHEMA [sp_csv]

-- %%
CREATE EXTERNAL DATA SOURCE SqlStoragePool
WITH (LOCATION = 'sqlhdfs://controller-svc/default');

-- %%
CREATE EXTERNAL FILE FORMAT [CSV]
WITH (FORMAT_TYPE = DELIMITEDTEXT, FORMAT_OPTIONS (FIELD_TERMINATOR = N',', STRING_DELIMITER = N'\"', FIRST_ROW = 2));

-- %%
 CREATE EXTERNAL FILE FORMAT parquet_file    
 WITH (FORMAT_TYPE = PARQUET);

-- %%
CREATE EXTERNAL TABLE [sp_csv].[population]
(
  [Country] nvarchar(100) NOT NULL,
  [Population] bigint NOT NULL
)
WITH (LOCATION = N'/covid/csv/population/', DATA_SOURCE = [SqlStoragePool], FILE_FORMAT = [CSV]);

-- %%
    CREATE EXTERNAL TABLE [sp_parquet].[covid_recovered]
    ("Province" VARCHAR(50) , "Country" VARCHAR(50) , "Date" Date, "recovered" BIGINT)
    WITH
    (
        DATA_SOURCE = SqlStoragePool,
        LOCATION = '/covid/parquet/recovered',
        FILE_FORMAT = parquet_file
    );

-- %%
    CREATE EXTERNAL TABLE [sp_parquet].[covid_confirmed]
    ("Province" VARCHAR(50) , "Country" VARCHAR(50) , "Date" Date, "confirmed" BIGINT)
    WITH
    (
        DATA_SOURCE = SqlStoragePool,
        LOCATION = '/covid/parquet/confirmed',
        FILE_FORMAT = parquet_file
    );

-- %%
    CREATE EXTERNAL TABLE [sp_parquet].[covid_deaths]
    ("Province" VARCHAR(50) , "Country" VARCHAR(50) , "Date" Date, "deaths" BIGINT)
    WITH
    (
        DATA_SOURCE = SqlStoragePool,
        LOCATION = '/covid/parquet/deaths',
        FILE_FORMAT = parquet_file
    );

-- %%
IF NOT EXISTS(SELECT * FROM sys.external_data_sources WHERE name = 'SqlDataPool')
        CREATE EXTERNAL DATA SOURCE SqlDataPool
        WITH (LOCATION = 'sqldatapool://controller-svc/default');

-- %%
CREATE EXTERNAL TABLE [dp].[Covid_Development](
	[Country] [varchar](50) NULL,
	[DTE] [date] NULL,
	[DTE_Str] [nvarchar](10) NULL,
	[Confirmed] [bigint] NULL,
	[Recovered] [bigint] NULL,
	[Deaths] [bigint] NULL,
	[Active] [bigint] NULL
)
    WITH
    (
    DATA_SOURCE = SqlDataPool,
    DISTRIBUTION = ROUND_ROBIN
    );
GO

-- %%
CREATE TABLE [mi].[Mapping_Country](
	[Ctry_Covid] [varchar](50) NULL,
	[Ctry_Population] [varchar](50) NULL
) ON [PRIMARY]

-- %%
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Belarus', N'Belarus')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Cameroon', N'Cameroon')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Afghanistan', N'Afghanistan')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Argentina', N'Argentina')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Angola', N'Angola')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Azerbaijan', N'Azerbaijan')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Andorra', N'Andorra')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Albania', N'Albania')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Bhutan', N'Bhutan')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Comoros', N'Comoros')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Austria', N'Austria')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Bahamas', N'Bahamas, The')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Antigua and Barbuda', N'Antigua and Barbuda')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Bosnia and Herzegovina', N'Bosnia and Herzegovina')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Barbados', N'Barbados')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Algeria', N'Algeria')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Botswana', N'Botswana')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Congo (Kinshasa)', N'Congo, Dem. Rep.')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Bangladesh', N'Bangladesh')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Bahrain', N'Bahrain')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Armenia', N'Armenia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Bulgaria', N'Bulgaria')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Bolivia', N'Bolivia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Belize', N'Belize')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Central African Republic', N'Central African Republic')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Croatia', N'Croatia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Brunei', N'Brunei Darussalam')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Brazil', N'Brazil')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Australia', N'Australia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Burma', N'Myanmar')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Colombia', N'Colombia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Burkina Faso', N'Burkina Faso')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'China', N'China')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Cuba', N'Cuba')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Cambodia', N'Cambodia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Chile', N'Chile')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Belgium', N'Belgium')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Grenada', N'Grenada')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Ghana', N'Ghana')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Burundi', N'Burundi')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Eswatini', N'Eswatini')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Cyprus', N'Cyprus')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Chad', N'Chad')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'France', N'France')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Benin', N'Benin')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Guinea-Bissau', N'Guinea-Bissau')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Holy See', N'Other small states')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Cabo Verde', N'Cabo Verde')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Fiji', N'Fiji')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Djibouti', N'Djibouti')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Congo (Brazzaville)', N'Congo, Rep.')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Gambia', N'Gambia, The')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Costa Rica', N'Costa Rica')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Honduras', N'Honduras')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Hungary', N'Hungary')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Canada', N'Canada')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Israel', N'Israel')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Dominica', N'Dominica')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Egypt', N'Egypt, Arab Rep.')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Guyana', N'Guyana')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Cote d''Ivoire', N'Cote d''Ivoire')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Indonesia', N'Indonesia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'India', N'India')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Diamond Princess', N'Other small states')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Jamaica', N'Jamaica')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Ethiopia', N'Ethiopia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Equatorial Guinea', N'Equatorial Guinea')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Iran', N'Iran, Islamic Rep.')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Czechia', N'Czech Republic')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Kuwait', N'Kuwait')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Italy', N'Italy')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'El Salvador', N'El Salvador')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Japan', N'Japan')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Georgia', N'Georgia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Eritrea', N'Somalia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Iraq', N'Iraq')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Denmark', N'Denmark')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Luxembourg', N'Luxembourg')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Jordan', N'Jordan')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Gabon', N'Gabon')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Kazakhstan', N'Kazakhstan')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Nicaragua', N'Nicaragua')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Greece', N'Greece')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Laos', N'Lao PDR')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Dominican Republic', N'Dominican Republic')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Mali', N'Mali')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Liechtenstein', N'Liechtenstein')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Germany', N'Germany')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Korea, South', N'Korea, Rep.')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Niger', N'Niger')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Guinea', N'Guinea')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Latvia', N'Latvia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Ecuador', N'Ecuador')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Mauritania', N'Mauritania')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Malaysia', N'Malaysia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Haiti', N'Haiti')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Mauritius', N'Mauritius')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Qatar', N'Qatar')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Iceland', N'Iceland')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Liberia', N'Liberia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Estonia', N'Estonia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Moldova', N'Moldova')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Malta', N'Malta')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Kenya', N'Kenya')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Mozambique', N'Mozambique')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Sao Tome and Principe', N'Sao Tome and Principe')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Ireland', N'Ireland')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Libya', N'Libya')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Finland', N'Finland')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Mongolia', N'Mongolia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Nepal', N'Nepal')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Kosovo', N'Kosovo')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Papua New Guinea', N'Papua New Guinea')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Saudi Arabia', N'Saudi Arabia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Madagascar', N'Madagascar')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Morocco', N'Morocco')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Guatemala', N'Guatemala')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Netherlands', N'Netherlands')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Nigeria', N'Nigeria')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Lebanon', N'Lebanon')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Paraguay', N'Paraguay')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Sierra Leone', N'Sierra Leone')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Maldives', N'Maldives')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Namibia', N'Namibia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Kyrgyzstan', N'Kyrgyz Republic')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Saint Vincent and the Grenadines', N'St. Vincent and the Grenadines')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Suriname', N'Suriname')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Malawi', N'Malawi')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Rwanda', N'Rwanda')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Sudan', N'Sudan')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Monaco', N'Monaco')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'New Zealand', N'New Zealand')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Lesotho', N'Lesotho')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Senegal', N'Senegal')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'US', N'United States')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Mexico', N'Mexico')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Saint Kitts and Nevis', N'St. Kitts and Nevis')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Trinidad and Tobago', N'Trinidad and Tobago')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'MS Zaandam', N'Other small states')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'North Macedonia', N'North Macedonia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Lithuania', N'Lithuania')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Serbia', N'Serbia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Montenegro', N'Montenegro')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Sri Lanka', N'Sri Lanka')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Zimbabwe', N'Zimbabwe')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Panama', N'Panama')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Oman', N'Oman')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Peru', N'Peru')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Slovakia', N'Slovak Republic')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Norway', N'Norway')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Taiwan*', N'Taiwan*')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Romania', N'Romania')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Pakistan', N'Pakistan')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Russia', N'Russian Federation')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Spain', N'Spain')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Philippines', N'Philippines')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Tanzania', N'Tanzania')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Seychelles', N'Seychelles')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Poland', N'Poland')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'San Marino', N'San Marino')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Thailand', N'Thailand')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Portugal', N'Portugal')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Timor-Leste', N'Timor-Leste')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Somalia', N'Somalia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Saint Lucia', N'St. Lucia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Singapore', N'Singapore')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Togo', N'Togo')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'South Africa', N'South Africa')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Switzerland', N'Switzerland')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Slovenia', N'Slovenia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'South Sudan', N'South Sudan')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Yemen', N'Yemen, Rep.')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Ukraine', N'Ukraine')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Turkey', N'Turkey')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Tunisia', N'Tunisia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Sweden', N'Sweden')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Uruguay', N'Uruguay')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Zambia', N'Zambia')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Uganda', N'Uganda')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Syria', N'Syrian Arab Republic')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Venezuela', N'Venezuela, RB')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Uzbekistan', N'Uzbekistan')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Tajikistan', N'Tajikistan')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'West Bank and Gaza', N'West Bank and Gaza')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Vietnam', N'Vietnam')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'United Arab Emirates', N'United Arab Emirates')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'Western Sahara', N'Sub-Saharan Africa')
GO
INSERT [mi].[Mapping_Country] ([Ctry_Covid], [Ctry_Population]) VALUES (N'United Kingdom', N'United Kingdom')
GO
